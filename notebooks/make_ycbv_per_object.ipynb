# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import pandas as pd
import torch
from cosypose.config import LOCAL_DATA_DIR

friendly_names = (LOCAL_DATA_DIR / 'bop_datasets/ycbv/ycbv_friendly_names.txt').read_text()
friendly_names = {str(int(l.split(' ')[0])): l.split(' ')[1] for l in friendly_names.split('\n')[:-1]}

def make_errors_dict(key, result_id):
    x = torch.load(LOCAL_DATA_DIR / 'results' / result_id / 'results.pth.tar')
    eval_df = x['dfs']['posecnn_init/refiner/iteration=2']
    scores = eval_df[f'{key}_ntop=1_matching=CLASS']['gt']['AUC/objects']
    object_names = scores.objects.values
    this_friendly_names = [friendly_names[str(int(x.split('_')[1]))] for x in object_names]
    this_scores = {this_friendly_names[n]: scores.values[n] for n in range(len(scores))}
    return this_scores


def make_summary_df(result_id):
    metrics = dict()
    metrics_k = ['ADD', 'ADD-S', 'ADD(-S)']
    for k in metrics_k:
        scores = make_errors_dict(k, result_id)
        metrics[k] = scores
    names = list(metrics[metrics_k[0]].keys())
    names += ['mean']
    df = {'object': names}
    for k in metrics_k:
        df[k] = [metrics[k][o] * 100 if o != 'mean' else np.mean(list(metrics[k].values())) * 100 for o in names]
    df = pd.DataFrame(df)
    return pd.DataFrame(df).set_index('object')

result_id = 'ycbv-n_views=1--5154971130'
df = make_summary_df(result_id)

pd.options.display.float_format = '{:,.1f}'.format
df
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-67bd3604e621> in <module>
#      34
#      35 result_id = 'ycbv-n_views=1--5154971130'
# ---> 36 df = make_summary_df(result_id)
#      37
#      38 pd.options.display.float_format = '{:,.1f}'.format
#
# <ipython-input-5-67bd3604e621> in make_summary_df(result_id)
#      23     metrics_k = ['ADD', 'ADD-S', 'ADD(-S)']
#      24     for k in metrics_k:
# ---> 25         scores = make_errors_dict(k, result_id)
#      26         metrics[k] = scores
#      27     names = list(metrics[metrics_k[0]].keys())
#
# <ipython-input-5-67bd3604e621> in make_errors_dict(key, result_id)
#      12     x = torch.load(LOCAL_DATA_DIR / 'results' / result_id / 'results.pth.tar')
#      13     eval_df = x['dfs']['posecnn_init/refiner/iteration=2']
# ---> 14     scores = eval_df[f'{key}_ntop=1_matching=CLASS']['gt']['AUC/objects']
#      15     object_names = scores.objects.values
#      16     this_friendly_names = [friendly_names[str(int(x.split('_')[1]))] for x in object_names]
#
# KeyError: 'ADD_ntop=1_matching=CLASS'
